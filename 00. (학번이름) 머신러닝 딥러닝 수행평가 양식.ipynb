# %% [markdown]
# <a href="https://colab.research.google.com/github/dudgus7477/data26/blob/main/00.%20(%ED%95%99%EB%B2%88%EC%9D%B4%EB%A6%84)%20%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D%20%EB%94%A5%EB%9F%AC%EB%8B%9D%20%EC%88%98%ED%96%89%ED%8F%89%EA%B0%80%20%EC%96%91%EC%8B%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. 프로젝트 목표 수립
# ## 1) 목표 수립하기
# > 주제 :
#
#
# > 주제 선정 이유 :

# %% [markdown]
# ##2) 데이터 선정하기
#
# >출처 :
#
#   다운받은 파일도 같이 패들렛에 제출

# %%
#파일 업로드하기

# %% [markdown]
# #2. 프로그램 구현

# %% [markdown]
# ##사용한 알고리즘  :
# ### 1) 알고리즘 정의 및 원리 설명
# -

# %% [markdown]
# #3. 최종 결론
# ### 1)
# ### 2)
# ### 3)
#
#
#
#
#
# ```
# 프로젝트 성찰
# : 프로젝트를 진행하며 겪은 어려운점과 극복한 방법을 아래에 적어주세요.
#
# ```
